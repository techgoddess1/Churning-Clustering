# %% [markdown]
# # **Women In AI Analytics Project**
# #### An End-to-End Analytics Learning Workflow for Clustering Analysis
#
# ***Contributors to this Notebook:*** Frances Oparaocha
#
# ***Supervised by:*** Sam Ayo
#
# ## Results
# ### Assumptions of Clustering Analysis
#  - Assumptions of kmeans clustering
#       - The variables have the same variance
#       - Variance have the same average value
#       - The distribution of variables are symmetrical
#  -
#
# ### Expected Results
# 1. A predictive model that predicts the customer behaviour.
# 2. A documented API for interacting with this model that returns predictions based on input

# %% [markdown]
# ***This notebook solution is divided into 4 Sections, each constituting a workflow on its own:***
#
# - Part I: Initial Data Analysis and Preprocessing
# - Part II: EDA
# - Part III: Feature Engineering
# - Part IV: Predictions

# %% [markdown]
# #### <strong>Cumulative WORK FLOW</strong>
# 1. Import libaries and Data
# 2. Data inspection
# 3. EDA/Preprocessing - univariate graphical Exploration and visualization
#     - Data cleaning
#     - Data manipulation
#     - Feature engineering
#     - Hypothesis testing
# 4. Modelling & predicting using RNN, K-means, LGBM, XGBoost, Logistics Regression and 4 ors
# 5. Model evaluation

# %% [markdown]
# #### Setup
#
# ##### <strong>Library import</strong>
# Import all the required Python libraries.
#
# It is a good practice to organize the imported libraries by functionality, as shown below.

# %%
#pip install shap
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.1.1-py3-none-any.whl (16.7 MB)
#      --------------------------------------- 16.7/16.7 MB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\franc\appdata\roaming\python\python39\site-packages (from mlflow) (6.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (8.0.4)
# Collecting alembic<2
#   Downloading alembic-1.9.1-py3-none-any.whl (210 kB)
#      ------------------------------------- 210.4/210.4 kB 13.3 MB/s eta 0:00:00
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      ---------------------------------------- 82.3/82.3 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (4.11.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (2.28.1)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (3.3.4)
# Collecting pyarrow<11,>=4.0.0
#   Downloading pyarrow-10.0.1-cp39-cp39-win_amd64.whl (20.3 MB)
#      --------------------------------------- 20.3/20.3 MB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: Flask<3 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (1.1.2)
# Requirement already satisfied: scipy<2 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (1.9.1)
# Requirement already satisfied: cloudpickle<3 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (2.0.0)
# Requirement already satisfied: shap<1,>=0.40 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (0.41.0)
# Requirement already satisfied: entrypoints<1 in c:\users\franc\appdata\roaming\python\python39\site-packages (from mlflow) (0.4)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\franc\appdata\roaming\python\python39\site-packages (from mlflow) (3.0.3)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      -------------------------------------- 147.5/147.5 kB 8.6 MB/s eta 0:00:00
# Collecting querystring-parser<2
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: scikit-learn<2 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (1.0.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\franc\appdata\roaming\python\python39\site-packages (from mlflow) (3.20.2)
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ------------------------------------- 182.5/182.5 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2 in c:\users\franc\appdata\roaming\python\python39\site-packages (from mlflow) (1.4.4)
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Collecting waitress<3
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: packaging<23 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (21.3)
# Requirement already satisfied: pytz<2023 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (2022.1)
# Requirement already satisfied: numpy<2 in c:\users\franc\anaconda3\lib\site-packages (from mlflow) (1.21.5)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\franc\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.5)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\franc\appdata\roaming\python\python39\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.6.0)
# Collecting oauthlib>=3.1.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ---------------------------------------- 151.7/151.7 kB ? eta 0:00:00
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\franc\appdata\roaming\python\python39\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\franc\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: pywin32>=304 in c:\users\franc\appdata\roaming\python\python39\site-packages (from docker<7,>=4.0.0->mlflow) (305)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\franc\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (1.26.11)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\franc\appdata\roaming\python\python39\site-packages (from docker<7,>=4.0.0->mlflow) (1.4.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\franc\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\franc\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\franc\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\franc\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\franc\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\franc\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\franc\appdata\roaming\python\python39\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\franc\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\franc\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\franc\appdata\roaming\python\python39\site-packages (from matplotlib<4->mlflow) (9.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\franc\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\franc\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\franc\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2022.9.14)
# Requirement already satisfied: joblib>=0.11 in c:\users\franc\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\franc\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\franc\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\franc\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (4.64.1)
# Requirement already satisfied: numba in c:\users\franc\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (0.55.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\franc\anaconda3\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow) (1.1.1)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools in c:\users\franc\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (65.6.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\franc\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (0.38.0)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142900 sha256=6db2caaa2c6dc578b4d0a23decdb14840aa1ad05b911b1af3a29883a4ab21a7e
#   Stored in directory: c:\users\franc\appdata\local\pip\cache\wheels\b3\d4\24\ed7f421c3c600f3eee1a3a9e5c4aecc286a7622cac031918b7
# Successfully built databricks-cli
# Installing collected packages: waitress, sqlparse, smmap, querystring-parser, pyarrow, oauthlib, Mako, gitdb, docker, databricks-cli, alembic, gitpython, mlflow
# Successfully installed Mako-1.2.4 alembic-1.9.1 databricks-cli-0.17.4 docker-6.0.1 gitdb-4.0.10 gitpython-3.1.29 mlflow-2.1.1 oauthlib-3.2.2 pyarrow-10.0.1 querystring-parser-1.2.4 smmap-5.0.0 sqlparse-0.4.3 waitress-2.1.2
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Libraries for data analysis
import pandas as pd
import numpy as np

# Libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Libraries for modelling

# %% [markdown]
# #### Reading in the datasets

# %%
charges = pd.read_csv('charges.csv')
charges.head()
# Out:
#    customerID  tenure        contract paperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                paymentMethod  monthlyCharges  totalCharges churn
# 0           Electronic check           29.85         29.85    No
# 1               Mailed check           56.95       1889.50    No
# 2               Mailed check           53.85        108.15   Yes
# 3  Bank transfer (automatic)           42.30       1840.75    No
# 4           Electronic check           70.70        151.65   Yes

# %%
personal = pd.read_csv('personal.csv')
personal.head()
# Out:
#    customerID  gender partner dependents  age
# 0  5575-GNVDE    Male      No         No   41
# 1  3668-QPYBK    Male      No         No   58
# 2  7795-CFOCW    Male      No         No   61
# 3  9237-HQITU  Female      No         No   66
# 4  9305-CDSKC  Female      No         No   87

# %%
plan = pd.read_csv('plan.csv')
plan.head()
# Out:
#    customerID phoneService     multipleLines internetService onlineSecurity  \
# 0  5575-GNVDE          Yes                No             DSL            Yes
# 1  7795-CFOCW           No  No phone service             DSL            Yes
# 2  9237-HQITU          Yes                No     Fiber optic             No
# 3  1452-KIOVK          Yes               Yes     Fiber optic             No
# 4  6713-OKOMC           No  No phone service             DSL            Yes
#
#   onlineBackup deviceProtection techSupport streamingTV streamingMovies
# 0           No              Yes          No          No              No
# 1           No              Yes         Yes          No              No
# 2           No               No          No          No              No
# 3          Yes               No          No         Yes              No
# 4           No               No          No          No              No

# %% [markdown]
# #### Data Inspection

# %%
# Checking the shape of the datasets
print(plan.shape)
print(personal.shape)
print(charges.shape)
# Out:
# (3540, 10)
# (5283, 5)
# (7032, 8)

# %%
# Checking for duplicates
print(charges.duplicated().sum())
print(plan.duplicated().sum())
print(personal.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
# Checking the info 
print(personal.info())
print(charges.info())
print(plan.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  5283 non-null   object
#  1   gender      5283 non-null   object
#  2   partner     5283 non-null   object
#  3   dependents  5283 non-null   object
#  4   age         5283 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 206.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   tenure            7032 non-null   int64
#  2   contract          7032 non-null   object
#  3   paperlessBilling  7032 non-null   object
#  4   paymentMethod     7032 non-null   object
#  5   monthlyCharges    6577 non-null   float64
#  6   totalCharges      6577 non-null   float64
#  7   churn             7032 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 439.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3540 entries, 0 to 3539
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        3540 non-null   object
#  1   phoneService      3540 non-null   object
#  2   multipleLines     3540 non-null   object
#  3   internetService   3540 non-null   object
#  4   onlineSecurity    3540 non-null   object
#  5   onlineBackup      3540 non-null   object
#  6   deviceProtection  3540 non-null   object
#  7   techSupport       3540 non-null   object
#  8   streamingTV       3540 non-null   object
#  9   streamingMovies   3540 non-null   object
# dtypes: object(10)
# memory usage: 276.7+ KB
# None

# %%
# Checking for missing values
charges.isnull().sum()
# Out:
# customerID            0
# tenure                0
# contract              0
# paperlessBilling      0
# paymentMethod         0
# monthlyCharges      455
# totalCharges        455
# churn                 0
# dtype: int64

# %%
# Checking the statisitical distribution of the dataset
charges.describe().T
# Out:
#                  count         mean          std    min     25%      50%  \
# tenure          7032.0    32.421786    24.545260   1.00    9.00    29.00
# monthlyCharges  6577.0    64.654637    30.101974  18.25   35.25    70.30
# totalCharges    6577.0  2274.584719  2263.042489  18.80  399.45  1389.85
#
#                     75%      max
# tenure            55.00    72.00
# monthlyCharges    89.85   118.75
# totalCharges    3775.85  8684.80

# %%
# Checking the statisitical distribution of the dataset
personal.describe().T
# Out:
#       count       mean        std   min   25%   50%   75%   max
# age  5283.0  55.017414  20.040712  20.0  38.0  55.0  72.0  90.0

# %%
# Checking the statisitical distribution of the dataset
plan.describe().T
# Out:
#                  count unique          top  freq
# customerID        3540   3540   5575-GNVDE     1
# phoneService      3540      2          Yes  3207
# multipleLines     3540      3           No  1692
# internetService   3540      3  Fiber optic  1577
# onlineSecurity    3540      3           No  1745
# onlineBackup      3540      3           No  1529
# deviceProtection  3540      3           No  1528
# techSupport       3540      3           No  1759
# streamingTV       3540      3           No  1430
# streamingMovies   3540      3          Yes  1388

# %%
# Merging all the datasets 
df = charges.merge(personal, how='inner').merge(plan,how='inner')
df
# Out:
#       customerID  tenure        contract paperlessBilling  \
# 0     5575-GNVDE      34        One year               No
# 1     7795-CFOCW      45        One year               No
# 2     9237-HQITU       2  Month-to-month              Yes
# 3     1452-KIOVK      22  Month-to-month              Yes
# 4     6713-OKOMC      10  Month-to-month               No
# ...          ...     ...             ...              ...
# 3532  6894-LFHLY       1  Month-to-month              Yes
# 3533  8456-QDAVC      19  Month-to-month              Yes
# 3534  2569-WGERO      72        Two year              Yes
# 3535  2234-XADUH      72        One year              Yes
# 3536  3186-AJIEK      66        Two year              Yes
#
#                   paymentMethod  monthlyCharges  totalCharges churn  gender  \
# 0                  Mailed check           56.95       1889.50    No    Male
# 1     Bank transfer (automatic)           42.30       1840.75    No    Male
# 2              Electronic check           70.70        151.65   Yes  Female
# 3       Credit card (automatic)           89.10       1949.40    No    Male
# 4                  Mailed check           29.75        301.90    No  Female
# ...                         ...             ...           ...   ...     ...
# 3532           Electronic check           75.75         75.75   Yes    Male
# 3533  Bank transfer (automatic)           78.70       1495.10    No    Male
# 3534  Bank transfer (automatic)           21.15       1419.40    No  Female
# 3535    Credit card (automatic)             NaN           NaN    No  Female
# 3536  Bank transfer (automatic)          105.65       6844.50    No    Male
#
#      partner  ... age  phoneService     multipleLines internetService  \
# 0         No  ...  41           Yes                No             DSL
# 1         No  ...  61            No  No phone service             DSL
# 2         No  ...  66           Yes                No     Fiber optic
# 3         No  ...  39           Yes               Yes     Fiber optic
# 4         No  ...  39            No  No phone service             DSL
# ...      ...  ...  ..           ...               ...             ...
# 3532      No  ...  46           Yes               Yes     Fiber optic
# 3533      No  ...  24           Yes                No     Fiber optic
# 3534      No  ...  33           Yes                No              No
# 3535     Yes  ...  46           Yes               Yes     Fiber optic
# 3536      No  ...  36           Yes                No     Fiber optic
#
#            onlineSecurity         onlineBackup     deviceProtection  \
# 0                     Yes                   No                  Yes
# 1                     Yes                   No                  Yes
# 2                      No                   No                   No
# 3                      No                  Yes                   No
# 4                     Yes                   No                   No
# ...                   ...                  ...                  ...
# 3532                   No                   No                   No
# 3533                   No                   No                   No
# 3534  No internet service  No internet service  No internet service
# 3535                   No                  Yes                  Yes
# 3536                  Yes                   No                  Yes
#
#               techSupport          streamingTV      streamingMovies
# 0                      No                   No                   No
# 1                     Yes                   No                   No
# 2                      No                   No                   No
# 3                      No                  Yes                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 3532                   No                   No                   No
# 3533                   No                  Yes                   No
# 3534  No internet service  No internet service  No internet service
# 3535                   No                  Yes                  Yes
# 3536                  Yes                  Yes                  Yes
#
# [3537 rows x 21 columns]

# %%
# checking for missing values
df.isnull().sum()
# Out:
# customerID            0
# tenure                0
# contract              0
# paperlessBilling      0
# paymentMethod         0
# monthlyCharges      234
# totalCharges        234
# churn                 0
# gender                0
# partner               0
# dependents            0
# age                   0
# phoneService          0
# multipleLines         0
# internetService       0
# onlineSecurity        0
# onlineBackup          0
# deviceProtection      0
# techSupport           0
# streamingTV           0
# streamingMovies       0
# dtype: int64

# %%
# Viewing the number of rows and columns in the dataset
df.shape
# Out:
# (3537, 21)

# %%
df['monthlyCharges'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3532    False
# 3533    False
# 3534    False
# 3535     True
# 3536    False
# Name: monthlyCharges, Length: 3537, dtype: bool
